# %% [markdown]
# <a href="https://colab.research.google.com/github/sailakkshmiallada/Machine_Learning_projects/blob/main/Sleep_Pattern_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sleep_data.csv')

# %%
df.head()
# Out:
#          date  sleep_hours
# 0  2015-02-19     6.400000
# 1  2015-02-20     7.583333
# 2  2015-02-21     6.350000
# 3  2015-02-22     6.500000
# 4  2015-02-23     8.916667

# %%
df.tail()
# Out:
#             date  sleep_hours
# 2349  2021-12-25     7.933333
# 2350  2021-12-26     3.850000
# 2351  2021-12-29     6.175000
# 2352  2021-12-30     5.158333
# 2353  2021-12-31     5.908333

# %%
df.shape
# Out:
# (2354, 2)

# %%
df.columns
# Out:
# Index(['date', 'sleep_hours'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# date           0
# sleep_hours    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2354 non-null   object
#  1   sleep_hours  2354 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 36.9+ KB

# %%
df.describe()
# Out:
#        sleep_hours
# count  2354.000000
# mean      7.356560
# std       2.213308
# min       1.266667
# 25%       6.235417
# 50%       6.816667
# 75%       7.483333
# max      17.433333

# %%
df.nunique()
# Out:
# date           2354
# sleep_hours     604
# dtype: int64

# %%
df["date"]= pd.to_datetime(df["date"])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df['date'], y = df['sleep_hours'], 
             data = df, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = df['date'], y = df['sleep_hours'], 
             data = df, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.histplot(df['sleep_hours'], bins = 20, kde = True, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.distplot(df['sleep_hours'], bins = 20, kde = True)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(df['sleep_hours'], palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.violinplot(df['sleep_hours'], palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
df = df.set_index('date')

# %%
df1 = pd.read_csv('sleep_data_new.csv')

# %%
df1.head()
# Out:
#                                     type   sourceName      creationDate  \
# 0  HKCategoryTypeIdentifierSleepAnalysis  Sync Solver  19-04-2015 09:42
# 1  HKCategoryTypeIdentifierSleepAnalysis  Sync Solver  19-04-2015 09:42
# 2  HKCategoryTypeIdentifierSleepAnalysis  Sync Solver  19-04-2015 09:42
# 3  HKCategoryTypeIdentifierSleepAnalysis  Sync Solver  19-04-2015 09:42
# 4  HKCategoryTypeIdentifierSleepAnalysis  Sync Solver  19-04-2015 09:42
#
#           startDate           endDate  \
# 0  20-02-2015 01:45  20-02-2015 08:09
# 1  20-02-2015 01:39  20-02-2015 08:46
# 2  21-02-2015 01:59  21-02-2015 09:34
# 3  21-02-2015 01:52  21-02-2015 09:57
# 4  22-02-2015 02:50  22-02-2015 09:11
#
#                                            value sourceVersion device
# 0  HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 1              HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 2  HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 3              HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 4  HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN

# %%
df1.tail()
# Out:
#                                        type         sourceName  \
# 8029  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8030  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8031  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8032  HKCategoryTypeIdentifierSleepAnalysis       Rob’s iPhone
# 8033  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
#
#           creationDate         startDate           endDate  \
# 8029  31-12-2021 09:04  31-12-2021 04:25  31-12-2021 05:28
# 8030  31-12-2021 09:04  31-12-2021 05:31  31-12-2021 05:54
# 8031  31-12-2021 09:04  31-12-2021 06:22  31-12-2021 06:30
# 8032  31-12-2021 09:04  31-12-2021 02:06  31-12-2021 09:04
# 8033  31-12-2021 09:04  31-12-2021 06:37  31-12-2021 09:05
#
#                                               value sourceVersion device
# 8029  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8030  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8031  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8032              HKCategoryValueSleepAnalysisInBed          15.1    NaN
# 8033  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN

# %%
df1.shape
# Out:
# (8034, 8)

# %%
df1.columns
# Out:
# Index(['type', 'sourceName', 'creationDate', 'startDate', 'endDate', 'value',
#        'sourceVersion', 'device'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 44

# %%
df1 = df1.drop_duplicates()

# %%
df1.isnull().sum()
# Out:
# type                0
# sourceName          0
# creationDate        0
# startDate           0
# endDate             0
# value               0
# sourceVersion     272
# device           7876
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7990 entries, 0 to 8033
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           7990 non-null   object
#  1   sourceName     7990 non-null   object
#  2   creationDate   7990 non-null   object
#  3   startDate      7990 non-null   object
#  4   endDate        7990 non-null   object
#  5   value          7990 non-null   object
#  6   sourceVersion  7718 non-null   object
#  7   device         114 non-null    object
# dtypes: object(8)
# memory usage: 561.8+ KB

# %%
df1.nunique()
# Out:
# type                1
# sourceName          4
# creationDate      630
# startDate        5653
# endDate          7240
# value               2
# sourceVersion      29
# device              5
# dtype: int64

# %%
df1['sourceName'].unique()
# Out:
# array(['Sync Solver', 'Clock', 'Rob’s Apple\xa0Watch', 'Rob’s iPhone'],
#       dtype=object)

# %%
df1['sourceName'].value_counts()
# Out:
# Sync Solver          4320
# Rob’s Apple Watch    2282
# Rob’s iPhone         1274
# Clock                 114
# Name: sourceName, dtype: int64

# %%
# plt.figure(figsize=(15,6))
# sns.countplot('sourceName', data = df1, palette = 'hls')
# plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df1['sourceName'].value_counts(), labels=df1['sourceName'].value_counts().index, 
        autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('Source Name', size=20, **hfont) 
plt.show()

# %%
df1['value'].unique()
# Out:
# array(['HKCategoryValueSleepAnalysisAsleepUnspecified',
#        'HKCategoryValueSleepAnalysisInBed'], dtype=object)

# %%
df1['value'].value_counts()
# Out:
# HKCategoryValueSleepAnalysisAsleepUnspecified    4441
# HKCategoryValueSleepAnalysisInBed                3549
# Name: value, dtype: int64

# %%
# plt.figure(figsize=(15,6))
# sns.countplot('value', data = df1, palette = 'hls')
# plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df1['value'].value_counts(), labels=df1['value'].value_counts().index, 
        autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('Value', size=20, **hfont) 
plt.show()

# %%
df1['device'].unique()
# Out:
# array([nan,
#        '<<HKDevice: 0x2807b0f50>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.0>',
#        '<<HKDevice: 0x2807b0870>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.0.1>',
#        '<<HKDevice: 0x2807ac1e0>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1>',
#        '<<HKDevice: 0x2807ac140>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1.2>',
#        '<<HKDevice: 0x2807ad900>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1.2>'],
#       dtype=object)

# %%
df1['device'].value_counts()
# Out:
# <<HKDevice: 0x2807b0870>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.0.1>    47
# <<HKDevice: 0x2807ac1e0>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1>      25
# <<HKDevice: 0x2807ad900>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1.2>    20
# <<HKDevice: 0x2807b0f50>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.0>      12
# <<HKDevice: 0x2807ac140>, name:iPhone, manufacturer:Apple, model:iPhone, hardware:iPhone9,1, software:12.1.2>    10
# Name: device, dtype: int64

# %%
# plt.figure(figsize=(15,6))
# sns.countplot('device', data = df1, palette = 'hls')
# plt.xticks(rotation = 90)
# plt.show()

# %%
plt.figure(figsize=(30,20)) 
plt.pie(df1['device'].value_counts(), labels=df1['device'].value_counts().index, 
        autopct='%1.1f%%', textprops={ 'fontsize': 25,
                                           'color': 'black',
                                           'weight': 'bold',
                                           'family': 'serif' }) 
hfont = {'fontname':'serif', 'weight': 'bold'}
plt.title('Device', size=20, **hfont) 
plt.show()

# %%
df1["creationDate"]= pd.to_datetime(df1["creationDate"])
df1["startDate"]= pd.to_datetime(df1["startDate"])
df1["endDate"]= pd.to_datetime(df1["endDate"])

# %%
df1['Duration'] = df1["endDate"] - df1["startDate"]

# %%
df1
# Out:
#                                        type         sourceName  \
# 0     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 1     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 2     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 3     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 4     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# ...                                     ...                ...
# 8029  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8030  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8031  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8032  HKCategoryTypeIdentifierSleepAnalysis       Rob’s iPhone
# 8033  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
#
#             creationDate           startDate             endDate  \
# 0    2015-04-19 09:42:00 2015-02-20 01:45:00 2015-02-20 08:09:00
# 1    2015-04-19 09:42:00 2015-02-20 01:39:00 2015-02-20 08:46:00
# 2    2015-04-19 09:42:00 2015-02-21 01:59:00 2015-02-21 09:34:00
# 3    2015-04-19 09:42:00 2015-02-21 01:52:00 2015-02-21 09:57:00
# 4    2015-04-19 09:42:00 2015-02-22 02:50:00 2015-02-22 09:11:00
# ...                  ...                 ...                 ...
# 8029 2021-12-31 09:04:00 2021-12-31 04:25:00 2021-12-31 05:28:00
# 8030 2021-12-31 09:04:00 2021-12-31 05:31:00 2021-12-31 05:54:00
# 8031 2021-12-31 09:04:00 2021-12-31 06:22:00 2021-12-31 06:30:00
# 8032 2021-12-31 09:04:00 2021-12-31 02:06:00 2021-12-31 09:04:00
# 8033 2021-12-31 09:04:00 2021-12-31 06:37:00 2021-12-31 09:05:00
#
#                                               value sourceVersion device  \
# 0     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 1                 HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 2     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 3                 HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 4     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# ...                                             ...           ...    ...
# 8029  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8030  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8031  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8032              HKCategoryValueSleepAnalysisInBed          15.1    NaN
# 8033  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
#
#             Duration
# 0    0 days 06:24:00
# 1    0 days 07:07:00
# 2    0 days 07:35:00
# 3    0 days 08:05:00
# 4    0 days 06:21:00
# ...              ...
# 8029 0 days 01:03:00
# 8030 0 days 00:23:00
# 8031 0 days 00:08:00
# 8032 0 days 06:58:00
# 8033 0 days 02:28:00
#
# [7990 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7990 entries, 0 to 8033
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   type           7990 non-null   object
#  1   sourceName     7990 non-null   object
#  2   creationDate   7990 non-null   datetime64[ns]
#  3   startDate      7990 non-null   datetime64[ns]
#  4   endDate        7990 non-null   datetime64[ns]
#  5   value          7990 non-null   object
#  6   sourceVersion  7718 non-null   object
#  7   device         114 non-null    object
#  8   Duration       7990 non-null   timedelta64[ns]
# dtypes: datetime64[ns](3), object(5), timedelta64[ns](1)
# memory usage: 624.2+ KB

# %%
to_hours = lambda x: x.total_seconds() / 3600
df1['hours'] = df1['Duration'].apply(to_hours)

# %%
df1
# Out:
#                                        type         sourceName  \
# 0     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 1     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 2     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 3     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# 4     HKCategoryTypeIdentifierSleepAnalysis        Sync Solver
# ...                                     ...                ...
# 8029  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8030  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8031  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
# 8032  HKCategoryTypeIdentifierSleepAnalysis       Rob’s iPhone
# 8033  HKCategoryTypeIdentifierSleepAnalysis  Rob’s Apple Watch
#
#             creationDate           startDate             endDate  \
# 0    2015-04-19 09:42:00 2015-02-20 01:45:00 2015-02-20 08:09:00
# 1    2015-04-19 09:42:00 2015-02-20 01:39:00 2015-02-20 08:46:00
# 2    2015-04-19 09:42:00 2015-02-21 01:59:00 2015-02-21 09:34:00
# 3    2015-04-19 09:42:00 2015-02-21 01:52:00 2015-02-21 09:57:00
# 4    2015-04-19 09:42:00 2015-02-22 02:50:00 2015-02-22 09:11:00
# ...                  ...                 ...                 ...
# 8029 2021-12-31 09:04:00 2021-12-31 04:25:00 2021-12-31 05:28:00
# 8030 2021-12-31 09:04:00 2021-12-31 05:31:00 2021-12-31 05:54:00
# 8031 2021-12-31 09:04:00 2021-12-31 06:22:00 2021-12-31 06:30:00
# 8032 2021-12-31 09:04:00 2021-12-31 02:06:00 2021-12-31 09:04:00
# 8033 2021-12-31 09:04:00 2021-12-31 06:37:00 2021-12-31 09:05:00
#
#                                               value sourceVersion device  \
# 0     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 1                 HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 2     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# 3                 HKCategoryValueSleepAnalysisInBed           NaN    NaN
# 4     HKCategoryValueSleepAnalysisAsleepUnspecified           NaN    NaN
# ...                                             ...           ...    ...
# 8029  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8030  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8031  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
# 8032              HKCategoryValueSleepAnalysisInBed          15.1    NaN
# 8033  HKCategoryValueSleepAnalysisAsleepUnspecified           8.3    NaN
#
#             Duration     hours
# 0    0 days 06:24:00  6.400000
# 1    0 days 07:07:00  7.116667
# 2    0 days 07:35:00  7.583333
# 3    0 days 08:05:00  8.083333
# 4    0 days 06:21:00  6.350000
# ...              ...       ...
# 8029 0 days 01:03:00  1.050000
# 8030 0 days 00:23:00  0.383333
# 8031 0 days 00:08:00  0.133333
# 8032 0 days 06:58:00  6.966667
# 8033 0 days 02:28:00  2.466667
#
# [7990 rows x 10 columns]

# %%
plt.figure(figsize=(15,6))
sns.histplot(df1['hours'], bins = 2, kde = True, palette = 'hls')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.distplot(df1['hours'], bins = 2, kde = True)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x = df1['creationDate'], y = df1['hours'], 
             data = df1, palette = 'hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x = df1['sourceName'], y = df1['hours'], 
             data = df1, ci = None, palette = 'hls')
plt.show()

# %%
import statsmodels.api as sm

# %%
sm.graphics.tsa.plot_acf(df)
plt.show()
sm.graphics.tsa.plot_acf(df, lags=30)
plt.show()

# %%
from matplotlib import pyplot
from pandas.plotting import lag_plot
lag_plot(df)
pyplot.show()

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error

# %%
model = AutoReg(df, lags=20)
model_fit = model.fit()
print('Coefficients: %s' % model_fit.params)
# Out:
# Coefficients: const              0.193272
# sleep_hours.L1     0.114887
# sleep_hours.L2     0.131713
# sleep_hours.L3     0.135941
# sleep_hours.L4     0.121907
# sleep_hours.L5     0.109834
# sleep_hours.L6     0.081247
# sleep_hours.L7     0.064662
# sleep_hours.L8     0.013882
# sleep_hours.L9     0.005718
# sleep_hours.L10    0.009981
# sleep_hours.L11    0.001046
# sleep_hours.L12    0.021532
# sleep_hours.L13    0.022663
# sleep_hours.L14    0.060778
# sleep_hours.L15    0.033026
# sleep_hours.L16    0.014353
# sleep_hours.L17    0.027143
# sleep_hours.L18   -0.030877
# sleep_hours.L19   -0.021163
# sleep_hours.L20    0.055161
# dtype: float64
# /usr/local/lib/python3.9/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
